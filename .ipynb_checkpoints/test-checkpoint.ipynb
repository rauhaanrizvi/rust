# %%
import matplotlib.pyplot as plt
import numpy as np

# Prepare the data
x = np.linspace(0, 150, 100)

# Plot the data
plt.plot(x, x, label='linear')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
y = 1000
z = y * 14
z
# Out:
# 14000
